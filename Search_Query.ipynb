# %% [markdown]
# <a href="https://colab.research.google.com/github/alokchoudharyguliya/Transformers/blob/main/Search_Query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Challenge Link - https://www.aicrowd.com/challenges/esci-challenge-for-improving-product-search

# %%
# !pip install aicrowd-cli

# %%
# !aicrowd login

# %%
# !aicrowd dataset download -c esci-challenge-for-improving-product-search

# %%
# !unzip "/content/train-v0.3.csv.zip" -d "/content/dataset"
# Out:
# Archive:  /content/train-v0.3.csv.zip
#   inflating: /content/dataset/data/processed/public/task_3_product_substitute_identification/train-v0.3.csv

# %%
# !unzip "/content/product_catalogue-v0.3.csv.zip" -d "/content/dataset"
# Out:
# Archive:  /content/product_catalogue-v0.3.csv.zip
#   inflating: /content/dataset/data/processed/public/task_3_product_substitute_identification/product_catalogue-v0.3.csv

# %%
# !cp /content/dataset/data/processed/public/task_3_product_substitute_identification/train-v0.3.csv "/content/drive/MyDrive/Query-Search Engine Dataset"

# %%
# !cp /content/dataset/data/processed/public/task_3_product_substitute_identification/product_catalogue-v0.3.csv "/content/drive/MyDrive/Query-Search Engine Dataset"

# %%
import numpy as np, pandas as pd, os

# %%
filepath_train="/content/drive/MyDrive/Query-Search Engine Dataset/train-v0.3.csv"
filepath_catalogue="/content/drive/MyDrive/Query-Search Engine Dataset/product_catalogue-v0.3.csv"

# %%
df_catalogue=pd.read_csv(filepath_catalogue)
df_train=pd.read_csv(filepath_train)

# %%
df_train
# Out:
#          example_id       query  product_id query_locale substitute_label
# 0                 0  11 degrees  B079VKKJN7           es    no_substitute
# 1                 1  11 degrees  B079Y9VRKS           es    no_substitute
# 2                 2  11 degrees  B07D2DDCZH           es    no_substitute
# 3                 3  11 degrees  B07DP4LM9H           es    no_substitute
# 4                 4  11 degrees  B07G37B9HP           es    no_substitute
# ...             ...         ...         ...          ...              ...
# 1834739     1834739    針なしほっちきす  B08XGQ9RH7           jp       substitute
# 1834740     1834740    針なしほっちきす  B0987RGRF2           jp    no_substitute
# 1834741     1834741    針なしほっちきす  B099NFJWP6           jp    no_substitute
# 1834742     1834742    針なしほっちきす  B09F3B413J           jp    no_substitute
# 1834743     1834743    針なしほっちきす  B09F3F1KDP           jp    no_substitute
#
# [1834744 rows x 5 columns]

# %%
df_catalogue
# Out:
#          product_id                                      product_title  \
# 0        B079VKKJN7  11 Degrees de los Hombres Playera con Logo, Ne...
# 1        B079Y9VRKS          Camiseta Eleven Degrees Core TS White (M)
# 2        B07DP4LM9H  11 Degrees de los Hombres Core Pull Over Hoodi...
# 3        B07G37B9HP          11 Degrees Poli Panel Track Pant XL Black
# 4        B07LCTGDHY  11 Degrees Gorra Trucker Negro OSFA (Talla úni...
# ...             ...                                                ...
# 1815211  B09FJYBVKS  スポーツブラ 揺れない ヨガウェア レディース トップス 通気性 ナイトブラ スポーツブラジ...
# 1815212  B09FTJ3S1N  ブラジャー レディース 補正ブラ Gabrioir 揺れない 大きいサイズ バストアップ美胸...
# 1815213  B09G72LDQZ  レディース ブラジャー 補正ブラ トップス Gabrioir 大きいサイズ 揺れない 脇高設...
# 1815214  B09GBGRTPB  ナイトブラ ノンワイヤーブラ ブラジャー レディース Gabrioir 大きいサイズ パット...
# 1815215  B09GBKN83Q  インナーキャミソール レディース ブラトップ キャミソール Gabrioir ノーワイヤー ...
#
#                                        product_description  \
# ...

# %%
df_train.shape
# Out:
# (1834744, 5)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1834744 entries, 0 to 1834743
# Data columns (total 5 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   example_id        int64
#  1   query             object
#  2   product_id        object
#  3   query_locale      object
#  4   substitute_label  object
# dtypes: int64(1), object(4)
# memory usage: 70.0+ MB

# %%
df_train.describe()
# Out:
#          example_id
# count  1.834744e+06
# mean   9.173715e+05
# std    5.296451e+05
# min    0.000000e+00
# 25%    4.586858e+05
# 50%    9.173715e+05
# 75%    1.376057e+06
# max    1.834743e+06

# %%
df_train.isna().sum()
# Out:
# example_id          0
# query               0
# product_id          0
# query_locale        0
# substitute_label    0
# dtype: int64

# %%
def get_label(label):
  if label=='exact':
    return 1.0
  elif label=='substitute':
    return 0.7
  elif label=='complement':
    return 0.5
  else:
    return 0.0

# %%
model_id=''

# %%
model=TFAutoModel.from_pretrained(model_id)
model.summary()

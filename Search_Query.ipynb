# %% [markdown]
# <a href="https://colab.research.google.com/github/alokchoudharyguliya/Transformers/blob/main/Search_Query.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Challenge Link - https://www.aicrowd.com/challenges/esci-challenge-for-improving-product-search

# %%
# !pip install aicrowd-cli
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !aicrowd login
# Out:
# Please login here: https://api.aicrowd.com/auth/UPzbN9Nplx_w6e11cSSwaTRYKB81M4d7TImVZ5qul9Y
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening 'https://api.aicrowd.com/auth/UPzbN9Nplx_w6e11cSSwaTRYKB81M4d7TImVZ5qul9Y'
# API Key valid
# Gitlab access token valid
# Saved details successfully!

# %%
# !aicrowd dataset download -c esci-challenge-for-improving-product-search
# Out:
# product_catalogue-v0.3.csv.zip: 100% 328M/328M [01:13<00:00, 4.46MB/s]
# sample_submission_public-v0.3.csv.zip: 100% 331k/331k [00:00<00:00, 399kB/s]
# test_public-v0.3.csv.zip: 100% 394k/394k [00:00<00:00, 465kB/s]
# train-v0.3.csv.zip: 100% 6.80M/6.80M [00:01<00:00, 4.13MB/s]
# product_catalogue-v0.3.csv.zip: 100% 657M/657M [00:47<00:00, 13.8MB/s]
# sample_submission_public-v0.3.csv.zip: 100% 812k/812k [00:01<00:00, 763kB/s]
# test_public-v0.3.csv.zip: 100% 2.94M/2.94M [00:01<00:00, 2.04MB/s]
# train-v0.3.csv.zip: 100% 19.8M/19.8M [00:02<00:00, 7.31MB/s]
# product_catalogue-v0.3.csv.zip:  36% 235M/657M [00:18<00:31, 13.4MB/s]
